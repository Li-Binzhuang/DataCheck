# %% [markdown]
# # CSV 文件读取与数据查询
#
# 本 Notebook 用于读取 CDC 特征文件并进行数据查询和探索。

# %% [markdown]
# # boss特征

# %%
# 导入必要的库
import json
from pathlib import Path
import numpy as np
import pandas as pd

print("库导入成功！")
# 读取 CSV 文件
# 注意：pd.read_csv() 使用 index_col 参数指定索引列，而不是 index

# 指定要读取的文件
csv_file_boss = 'outputs/boss_feature_data.csv'

# 读取数据
data_boss = pd.read_csv(csv_file_boss)

print(f"✓ 成功读取文件: {csv_file_boss}")
print(f"✓ 数据形状: {data_boss.shape} (行数 × 列数)")
print(f"\n前5行数据:")
data_boss.head()
# Out:
# ✓ 成功读取文件: outputs/boss_feature_data.csv
# ✓ 数据形状: (12546, 150) (行数 × 列数)
#
# 前5行数据:
#               apply_id             request_time  cdc_boss_total_accounts_607  \
# 0  1065991091661283329  2025-11-25 01:53:44.943                        142.0
# 1  1066560157648134145  2025-11-25 06:29:46.980                         16.0
# 2  1066719243236777985  2025-11-25 07:46:56.302                         14.0
# 3  1067025354145890305  2025-11-25 10:15:25.034                         73.0
# 4  1067575625355862017  2025-11-25 14:42:20.427                         20.0
#
#    cdc_boss_closed_accounts_cnt_607  cdc_boss_open_accounts_cnt_607  \
# 0                             111.0                            31.0
# 1                               6.0                            10.0
# 2                               9.0                             5.0
# 3                              53.0                            20.0
# 4                              14.0                             6.0
#
# ...

# %%
data_boss[(data_boss['apply_id'] == '1065991091661283329')&(data_boss['request_time'] == '2025-11-25 01:53:44.943')][['apply_id','cdc_boss_total_accounts_607']]
# Out:
#               apply_id  cdc_boss_total_accounts_607
# 0  1065991091661283329                        142.0

# %% [markdown]
# # 第一板块特征

# %%
# 导入必要的库
import json
from pathlib import Path
import numpy as np
import pandas as pd

print("库导入成功！")
# 读取 CSV 文件
# 注意：pd.read_csv() 使用 index_col 参数指定索引列，而不是 index

# 指定要读取的文件
csv_file_cdc1 = 'outputs/cdc1_feature_data.csv'

# 读取数据
data_cdc1 = pd.read_csv(csv_file_cdc1)

print(f"✓ 成功读取文件: {csv_file_cdc1}")
print(f"✓ 数据形状: {data_cdc1.shape} (行数 × 列数)")
print(f"\n前5行数据:")
data_cdc1.head()
# Out:
# 库导入成功！
# ✓ 成功读取文件: outputs/cdc1_feature_data.csv
# ✓ 数据形状: (12546, 989) (行数 × 列数)
#
# 前5行数据:
#               apply_id             request_time  \
# 0  1065462364007251969  2025-11-24 21:37:16.301
# 1  1065471950374248449  2025-11-24 21:41:55.655
# 2  1065474664793579521  2025-11-24 21:43:14.452
# 3  1065474733513048065  2025-11-24 21:43:16.834
# 4  1065474836592279553  2025-11-24 21:43:19.638
#
#    cdc_consultas_30d_total_cnt_v2  cdc_consultas_30d_shop_cnt_v2  \
# 0                               6                              0
# 1                               2                              0
# 2                               6                              0
# 3                              11                              0
# 4                               2                              0
#
#    cdc_consultas_30d_shop_ratio_v2  cdc_consultas_30d_shop_days_mean_v2  \
# 0                              0.0                                  NaN
# ...

# %%
data_cdc1[(data_cdc1['apply_id'] == 1065462364007251969)&(data_cdc1['request_time'] == '2025-11-24 21:37:16.301')][['apply_id','request_time','cdc_consultas_30d_total_cnt_v2']]
# Out:
#               apply_id             request_time  \
# 0  1065462364007251969  2025-11-24 21:37:16.301
#
#    cdc_consultas_30d_total_cnt_v2
# 0                               6

# %% [markdown]
# # 第二板块特征

# %%
# 导入必要的库
import json
from pathlib import Path
import numpy as np
import pandas as pd

print("库导入成功！")

# 读取 CSV 文件
# 注意：pd.read_csv() 使用 index_col 参数指定索引列，而不是 index

# 指定要读取的文件
csv_file_cdc2= 'outputs/cdc2_feature_data.csv'

# 读取数据
data_cdc2 = pd.read_csv(csv_file_cdc2)

print(f"✓ 成功读取文件: {csv_file_cdc2}")
print(f"✓ 数据形状: {data_cdc1.shape} (行数 × 列数)")
print(f"\n前5行数据:")
data_cdc2.head()

# %% [markdown]
# # 第三板块特征

# %%
# 导入必要的库
import json
from pathlib import Path
import numpy as np
import pandas as pd

print("库导入成功！")
# 读取 CSV 文件
# 注意：pd.read_csv() 使用 index_col 参数指定索引列，而不是 index

# 指定要读取的文件
csv_file_cdc3= 'outputs/cdc3_feature_data.csv'

# 读取数据
data_cdc3 = pd.read_csv(csv_file_cdc3)

print(f"✓ 成功读取文件: {csv_file_cdc3}")
print(f"✓ 数据形状: {data_cdc1.shape} (行数 × 列数)")
print(f"\n前5行数据:")
data_cdc3.head()

# %%
# 导出筛选结果（可选）
# 如果需要将查询结果导出为新的 CSV 文件

# output_file = 'outputs/filtered_data.csv'
# result.to_csv(output_file, index=False, encoding='utf-8-sig')
# print(f"结果已导出到: {output_file}")
